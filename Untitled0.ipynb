# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("/content/drive/MyDrive/archive/train_u6lujuX_CVtuZ9i.csv")

# %%
a
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a['Education']
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %%
a[['Education','Self_Employed']]
# Out:
#         Education Self_Employed
# 0        Graduate            No
# 1        Graduate            No
# 2        Graduate           Yes
# 3    Not Graduate            No
# 4        Graduate            No
# ..            ...           ...
# 609      Graduate            No
# 610      Graduate            No
# 611      Graduate            No
# 612      Graduate            No
# 613      Graduate           Yes
#
# [614 rows x 2 columns]

# %%
type(['Education'])
# Out:
# list

# %%
a['new']=a['ApplicantIncome']+a['CoapplicantIncome']
a
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.loc[1]
# Out:
# Loan_ID              LP001003
# Gender                   Male
# Married                   Yes
# Dependents                  1
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          4583
# CoapplicantIncome      1508.0
# LoanAmount              128.0
# Loan_Amount_Term        360.0
# Credit_History            1.0
# Property_Area           Rural
# Loan_Status                 N
# new                    6091.0
# Name: 1, dtype: object

# %%
a.drop(0,axis=0)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.loc[0]
# Out:
# Loan_ID              LP001002
# Gender                   Male
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          5849
# CoapplicantIncome         0.0
# LoanAmount                NaN
# Loan_Amount_Term        360.0
# Credit_History            1.0
# Property_Area           Urban
# Loan_Status                 Y
# new                    5849.0
# Name: 0, dtype: object

# %%
a.groupby('Education')
